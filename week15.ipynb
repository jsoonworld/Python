# %% [markdown]
# #이터러블, 이터레이터, 제너레이터 함수와 제너레이터 표현식

# %% [markdown]
# ![스크린샷 2023-01-05 오후 12.20.24.png](data:image/png;base64,...)

# %% [markdown]
# ![스크린샷 2023-01-05 오후 12.20.56.png](data:image/png;base64,...)

# %% [markdown]
# ![스크린샷 2023-01-05 오후 12.21.11.png](data:image/png;base64,...)

# %% [markdown]
# ![스크린샷 2023-01-05 오후 12.21.55.png](data:image/png;base64,...)

# %% [markdown]
# ![스크린샷 2023-01-05 오후 12.22.45.png](data:image/png;base64,...)

# %% [markdown]
# #가독성과 유지보수성
#
# ##함수를 사용하는 이유

# %% [markdown]
# ![스크린샷 2023-01-05 오후 12.37.59.png](data:image/png;base64,...)

# %% [markdown]
# ![스크린샷 2023-01-05 오후 12.41.03.png](data:image/png;base64,...)
