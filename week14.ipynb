# %% [markdown]
# #튜플 tuple

# %%
a = (1, 2, 3)
print(a)
print(a[0])

b = (1, )
print(b)

c = 1, 
print(c)
# Out:
# (1, 2, 3)
# 1
# (1,)
# (1,)

# %% [markdown]
# #튜플과 리스트의 차이
#
# ##외관이 간단!
#
# #요소를 변경할 수 없다!

# %% [markdown]
# ![스크린샷 2023-01-04 오후 9.11.26.png](data:image/png;base64,...)

# %% [markdown]
# ![스크린샷 2023-01-04 오후 9.12.36.png](data:image/png;base64,...)

# %% [markdown]
# ![스크린샷 2023-01-04 오후 9.14.44.png](data:image/png;base64,...)

# %% [markdown]
# ![스크린샷 2023-01-04 오후 9.16.47.png](data:image/png;base64,...)

# %% [markdown]
# ![스크린샷 2023-01-04 오후 9.21.09.png](data:image/png;base64,...)

# %% [markdown]
# ![스크린샷 2023-01-04 오후 9.23.22.png](data:image/png;base64,...)

# %% [markdown]
# ![스크린샷 2023-01-04 오후 9.24.47.png](data:image/png;base64,...)

# %% [markdown]
# ![스크린샷 2023-01-04 오후 9.26.20.png](data:image/png;base64,...)

# %% [markdown]
# ![스크린샷 2023-01-04 오후 9.35.51.png](data:image/png;base64,...)

# %% [markdown]
# ![스크린샷 2023-01-04 오후 9.38.26.png](data:image/png;base64,...)
