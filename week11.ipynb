# %% [markdown]
# #시간 복잡도
# ##time complexity
#
# ###큰 숫자를 대입 하면 계수 등의 것들은 의미를 가지지 않기 떄문에 Big O notaion으로 표기

# %% [markdown]
# #현실적인 time complexity
#
# ##작은 숫자는  n^2
# ##큰 숫자는 nlong n

# %% [markdown]
# #함수![스크린샷 2022-12-31 오후 8.22.20.png](data:image/png;base64,...)
